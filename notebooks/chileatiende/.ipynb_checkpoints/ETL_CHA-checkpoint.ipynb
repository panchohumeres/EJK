# %%
import requests
import pandas as pd
import numpy as np
import sys
from importlib import reload
import os.path
from os import path
import sys

# %%
sys.path.append('..') #agregar directorio madre del repo para poder importar librerias customizadas
#importar librerias customizadas

# %%
import modules.html_process
reload(modules.html_process)
# Out:
# <module 'modules.html_process' from '../modules/html_process.py'>

# %%
from modules.html_process import *

# %%
url='https://www.chileatiende.gob.cl/api/fichas?access_token=q1bYCHOyXMOoAD6S&query=&maxResults=100&pageToken='

# %%
fichas=[]
for p in range(1,27):
    f=requests.get(url+str(p))
    f=f.json()
    f=f['fichas']['items']['ficha']
    for i in f:
        fichas.append(i)

# %%
len(fichas)
# Out:
# 2537

# %%
fichascha=pd.DataFrame(fichas) #convertir las fichas a dataframe pandas
fichascha['id']=fichascha['id'].astype('object') #convertir campo id a tipo 'object'

# %%
fichascha=html_process(fichascha) #convertirla a objeto 'html_process' para borrar tags html de campos string

# %%
fichascha.fields=['objetivo','detalle','beneficiarios','costo','doc_requeridos','vigencia','guia_oficina',
                 'guia_online','guia_online_url','guia_oficina','guia_correo','guia_telefonico','guia_consulado'
                 
                 ] #setear campos en los cuales borrar html tags

# %%
fichascha.remove_html_tags_pattern() #ejecutar función de limpieza de tags html en campos string

# %%
fichascha=fichascha.df #devolver resultados a df original

# %%
#cambios de nombre de campos para estandarizar con RNT

rnt_mapping={'permalink':'url_chileatiende', #url de la ficha chileatiende
 'marco_legal':'url_marco_legal', #url marco legal
 'guia_online_url': 'url_guia_institucional', #url descripción institucional

}

# %%
fichascha=fichascha.rename(columns=rnt_mapping)

# %%
#flag de si tiene atención presencial---->para homologar con RNT
fichascha['atencion_presencial']='No' #asumir a priori todos valores 'No', luego cambiar con operaciones de abajo a 'Si' casos que corresponde
fichascha.loc[fichascha['guia_oficina'].str.replace(' ','').str.len()>0,'guia_oficina']='Si' #registros que no están blanco
fichascha.loc[fichascha['guia_oficina'].notnull(),'atencion_presencial']='Si' #registros que no son nulos

# %%
#flag de si tiene atención telefonico---->para homologar con RNT
fichascha['atencion_telefonico']='No' #asumir a priori todos valores 'No', luego cambiar con operaciones de abajo a 'Si' casos que corresponde
fichascha.loc[fichascha['guia_telefonico'].str.replace(' ','').str.len()>0,'guia_telefonico']='Si' #registros que no están blanco
fichascha.loc[fichascha['guia_telefonico'].notnull(),'atencion_telefonico']='Si' #registros que no son nulos

# %%
#flag de si tiene atención digital (asumido a partir de guia online url)---->para homologar con RNT
fichascha['atencion_digital']='No' #asumir a priori todos valores 'No', luego cambiar con operaciones de abajo a 'Si' casos que corresponde
fichascha.loc[fichascha['guia_online'].str.replace(' ','').str.len()>0,'guia_online']='Si' #registros que no están blanco
fichascha.loc[fichascha['guia_online'].notnull(),'atencion_digital']='Si' #registros que no son nulos

# %%
#flag de fichas que no tienen costo (gratis)---->para homologar con RNT
#descripción si tiene costo , valores ['No', 'Si', 'No informa', 'En algunos casos']
fichascha['Pago']='No informa' #valor por defecto
fichascha.loc[fichascha['costo'].str.contains('No tiene costo|no tiene costo'),'Pago']='No' #string 1 O ('|') string 2--->No tiene costo

# %%
#Incluir info si tiene pago
fichascha.loc[(fichascha['costo'].str.replace(' ','').str.len()>0) & (fichascha['Pago']!='No'),'Pago']='Si' #Tiene costo

# %%
#replace_values = {'No tiene costo' : '', 'no tiene costo' : '' , '.' : '',',':'',' ':'','\xa0':''}

# %%
#fichascha.replace({'costo':replace_values})['costo'].unique()

# %%
#fichascha['costo'][(fichascha['Pago']=='No') & fichascha['costo'].str.replace('No tiene costo|no tiene costo','')].unique()

# %%
fichascha.sample(10)
# Out:
#          id       codigo                                           servicio  \
# 254   10978      AB006-8                                 Servicio Electoral
# 1635  56619  AD022-56619             Subsecretaría para las Fuerzas Armadas
# 2452  60851  AP017-60851                   Parque Metropolitano de Santiago
# 2336    745      ZC005-9                      Corporación Nacional Forestal
# 2457   5194     AL005-23                      Instituto de Previsión Social
# 1350    328     AK008-14  Corporación de Asistencia Judicial Región Metr...
# 2318   4666      AM011-4           Superintendencia de Servicios Sanitarios
# 2517  33958    ZZ001-221                                       ChileAtiende
# 700   13438    AE006-113                     Servicio de Impuestos Internos
# 1198  23037     AI000-12          Ministerio de Desarrollo Social y Familia
#
#                     fecha                                             titulo  \
# 254   2020-01-02 00:00:00      Centro de documentación y normativa electoral
# 1635  2020-01-10 00:00:00  Otorgamiento o modificación sustancial de conc...
# 2452  2020-03-17 00:00:00     Horarios y tarifas de atractivos del Parquemet
# 2336  2020-01-07 00:00:00  Filmaciones o fotografías en áreas silvestres ...
# 2457  2020-02-18 00:00:00                                      Bono por Hijo
# 1350  2020-01-31 00:00:00  Asesoría jurídica para determinar el régimen d...
# 2318  2020-01-10 00:00:00  Renovación de la credencial de instaladores sa...
# 2517  2020-05-19 00:00:00                     Pensión Básica Solidaria (PBS)
# 700   2020-01-07 00:00:00                       Tasación fiscal de vehículos
# 1198  2020-01-02 00:00:00                               Programa Noche Digna
#
#                                                objetivo  \
# 254   Permite acceder a textos archivados en la bibl...
# 1635  Permite solicitar el otorgamiento de una conce...
# 2452  Permite conocer los horarios y tarifas de los ...
# 2336  Permite obtener un permiso para realizar filma...
# 2457  Es un beneficio que incrementa el monto de la ...
# 1350  Permite solicitar orientación y asesoría juríd...
# 2318  Permite solicitar la renovación de la credenci...
# 2517  Es un beneficio monetario mensual al que puede...
# 700   Permite conocer el valor de la tasación fiscal...
# 1198  Entrega alternativas de alojamiento temporal y...
#
#                                                 detalle  \
# 254
# 1635  Se refiere a bienes nacionales de uso público ...
# 2452
# 2336
# 2457
# 1350  La determinación de un régimen de relación dir...
# 2318
# 2517
# 700
# 1198
#
#                                           beneficiarios  \
# 254                                 Todas las personas.
# 1635   Para el otorgamiento, personas naturales o ju...
# 2452                                Todas las personas.
# 2336  Audiovisualistas, cineastas, realizadores o re...
# 2457   Madres afiliadas a una AFP que obtuvieron su ...
# 1350  A todos los padres y madres que no ejercen el ...
# 2318  Sólo instaladores sanitarios no profesionales ...
# 2517
# 700                     Personas naturales y jurídicas.
# 1198                    Personas en situación de calle.
#
#                                                   costo  \
# 254   Sólo costo de reproducción de lo requerido (fo...
# 1635  No tiene costo. Sin embargo, en caso de otorga...
# 2452                                    No tiene costo.
# 2336   Comerciales o filmaciones publicitarias: 50 U...
# 2457                                    No tiene costo.
# 1350  Para orientación e información, la Corporación...
# 2318                                    No tiene costo.
# 2517
# 700                                     No tiene costo.
# 1198                                    No tiene costo.
#
#                                         url_marco_legal  ...  \
# 254                                                      ...
# 1635  <p><a style="background-color: #ffffff;" href=...  ...
# 2452                                                     ...
# 2336  <p><a href="http://www.conaf.cl/cms/editorweb/...  ...
# 2457  <p><a href="http://www.leychile.cl/Navegar?idN...  ...
# 1350  <ul> <li>Artículos 229 y siguientes del <a hre...  ...
# 2318  <ul> <li><a href="http://www.siss.gob.cl/appsi...  ...
# 2517                                                     ...
# 700   <ul> <li><a href="http://www.sii.cl/normativa_...  ...
# 1198                                                     ...
#
#           updated_data_at observaciones         temas  \
# 254   2020-01-02 00:00:00                {'tema': []}
# 1635  2020-01-10 00:00:00                {'tema': []}
# 2452  2020-03-17 00:00:00                {'tema': []}
# 2336  2020-01-07 00:00:00                {'tema': []}
# 2457  2020-02-18 00:00:00                {'tema': []}
# 1350  2020-01-31 00:00:00                {'tema': []}
# 2318  2020-01-10 00:00:00                {'tema': []}
# 2517  2020-05-19 00:00:00                {'tema': []}
# 700   2020-01-07 00:00:00                {'tema': []}
# 1198  2020-01-02 00:00:00                {'tema': []}
#
#                                     tags chileclic_id  \
# 254                                   []         None
# 1635                 [Permiso Sectorial]         None
# 2452                                  []         None
# 2336                                  []         None
# 2457  [Familia, Previsión, Bonos, Mujer]         None
# 1350                             [Legal]         None
# 2318                           [Trabajo]         None
# 2517                         [Previsión]         None
# 700                              [Legal]         None
# 1198                                  []         None
#
#                                        url_chileatiende atencion_presencial  \
# 254   https://www.chileatiende.gob.cl/fichas/10978-c...                  Si
# 1635  https://www.chileatiende.gob.cl/fichas/56619-o...                  Si
# 2452  https://www.chileatiende.gob.cl/fichas/60851-h...                  Si
# 2336  https://www.chileatiende.gob.cl/fichas/745-fil...                  Si
# 2457  https://www.chileatiende.gob.cl/fichas/5194-bo...                  Si
# 1350  https://www.chileatiende.gob.cl/fichas/328-ase...                  Si
# 2318  https://www.chileatiende.gob.cl/fichas/4666-re...                  Si
# 2517  https://www.chileatiende.gob.cl/fichas/33958-p...                  Si
# 700   https://www.chileatiende.gob.cl/fichas/13438-c...                  Si
# 1198  https://www.chileatiende.gob.cl/fichas/23037-p...                  Si
#
#      atencion_telefonico atencion_digital        Pago
# 254                   Si               Si          Si
# 1635                  Si               Si          No
# 2452                  Si               Si          No
# 2336                  Si               Si          Si
# 2457                  Si               Si          No
# 1350                  Si               Si          Si
# 2318                  Si               Si          No
# 2517                  Si               Si  No informa
# 700                   Si               Si          No
# 1198                  Si               Si          No
#
# [10 rows x 29 columns]

# %%
import modules.Elastic_Module
reload(modules.Elastic_Module)
from modules.Elastic_Module import *

# %%
#variables de entorno
args={}
args['elastic_user']='elastic'
args['elastic_psswd']=os.environ['ELASTIC_PASSWD']

# %%
ES_HOST = "https://"
basic_auth={'user':args['elastic_user'], 'psswd':args['elastic_psswd']}

# %%
es=elastic_connection(ES_HOST,basic_auth=basic_auth)

# %%
es.ping()
# Out:
# True

# %%
{item: value for (item, value) in es.__dict__.item if }
# Out:
# {'es': <Elasticsearch([{'host': '', 'port': 443, 'use_ssl': True}])>}

# %%
indexes=[
    ('cha','cha')
        ]

# %%
#generateID_params={'x':'id','y':'_id'} #cambiar nombres de campos (parámetros)

# %%
#generar campos concatenados (parámetros)
#generateID_params_custom={'fields':['package_id','id'], #campos a concatenar
#                               'head':20, #numero de caracteres a dejar
#                                'sep':'_' #separador entre campos
#                               }

# %%
#es.generateID_params_custom=generateID_params_custom

# %%
#es.generateID_params=generateID_params

# %%
es.add_docs(fichascha)

# %%
es.docs
# Out:
#          id       codigo                                   servicio  \
# 0     77607  ZZ001-77607                               ChileAtiende
# 1      5268     AL005-51              Instituto de Previsión Social
# 2      5294     AL005-64              Instituto de Previsión Social
# 3     77255  AI000-77255  Ministerio de Desarrollo Social y Familia
# 4     64062  ZY002-64062       Administradora de Fondos de Cesantía
# ...     ...          ...                                        ...
# 2520   3982      AL009-6       Superintendencia de Seguridad Social
# 2521  22287     AL009-15       Superintendencia de Seguridad Social
# 2522  28964     AL009-17       Superintendencia de Seguridad Social
# 2523  59141  AL009-59141       Superintendencia de Seguridad Social
# 2524  59132  AL009-59132       Superintendencia de Seguridad Social
#
#                     fecha                                             titulo  \
# 0     2020-03-31 00:00:00                     Plan Solidario de Conectividad
# 1     2020-03-29 00:00:00  Modificación de forma de pago para beneficiari...
# 2     2020-04-06 00:00:00  Autorización para cobrar beneficios de previsi...
# 3     2020-04-08 00:00:00                        Bono de Emergencia COVID-19
# 4     2020-04-09 00:00:00       Acceder al Fondo de Cesantía Solidario (FCS)
# ...                   ...                                                ...
# 2520  2020-04-09 00:00:00  Reclamar o apelar el derecho del Subsidio por ...
# 2521  2020-04-09 00:00:00  Reclamar o apelar contra una Caja de Compensac...
# 2522  2020-04-09 00:00:00  Apelar o reclamar el rechazo o reducción de un...
# 2523  2020-04-09 00:00:00  Solicitud de audiencia o reunión a la Superint...
# 2524  2020-04-09 00:00:00  Solicitud de información pública a la Superint...
#
#                                                objetivo  \
# 0     El Ministerio de Transportes y Telecomunicacio...
# 1     Permite a personas que reciben algún beneficio...
# 2     Permite a una tercera persona actuar en repres...
# 3     Es un beneficio no postulable, anunciado como ...
# 4     Permite a a quienes no cuentan con recursos su...
# ...                                                 ...
# 2520  Permite reclamar ante la Superintendencia de S...
# 2521  Permite a trabajadores, trabajadoras, pensiona...
# 2522  Permite apelar o reclamar ante la Superintende...
# 2523  Permite solicitar una audiencia o reunión a un...
# 2524  Permite solicitar información pública a la Sup...
#
#                                                 detalle  \
# 0
# 1
# 2     Las formas en que se puede designar a un repre...
# 3
# 4     Los pagos con cargo al FCS se suspenderán auto...
# ...                                                 ...
# 2520  Importante:  El Subsidio por Incapacidad Labor...
# 2521
# 2522  Las licencias médicas de origen común son aque...
# 2523  La audiencia consiste en que el o la sujeto pa...
# 2524
#
#                                           beneficiarios            costo  \
# 0
# 1     Pensionados y pensionadas de las ex cajas de p...  No tiene costo.
# 2     Personas beneficiarias del IPS y pensionados y...  No tiene costo.
# 3     El bono COVID-19 está destinado a:  Familias q...  No tiene costo.
# 4     Trabajadores que se encuentran cesantes al mom...   No tiene costo
# ...                                                 ...              ...
# 2520  Trabajadores y trabajadoras dependientes e ind...  No tiene costo.
# 2521  Trabajadores, trabajadoras, pensionados y pens...  No tiene costo.
# 2522  Trabajadores y trabajadoras dependientes e ind...  No tiene costo.
# 2523                    Personas naturales y jurídicas.  No tiene costo.
# 2524                    Personas naturales y jurídicas.  No tiene costo.
#
#                                             marco_legal  ...  \
# 0                                                        ...
# 1                                                        ...
# 2                                                        ...
# 3     <p><a href="https://www.leychile.cl/Navegar?id...  ...
# 4     <ul> <li><a href="http://www.leychile.cl/Naveg...  ...
# ...                                                 ...  ...
# 2520  <p><a href="https://www.leychile.cl/Navegar?id...  ...
# 2521  <p><a href="http://www.leychile.cl/Navegar?idN...  ...
# 2522  <ul> <li><a href="http://www.leychile.cl/Naveg...  ...
# 2523  <ul> <li><a href="http://bcn.cl/1uwtr" target=...  ...
# 2524  <p><a href="http://www.leychile.cl/Navegar?idN...  ...
#
#                                                vigencia plazo  \
# 0
# 1
# 2      Dos años si no se tramita remotamente. Tres m...
# 3
# 4     El beneficio estará vigente mientras el trabaj...
# ...                                                 ...   ...
# 2520
# 2521
# 2522
# 2523
# 2524
#
#                                          doc_requeridos      updated_data_at  \
# 0                                                        2020-03-31 00:00:00
# 1     Para trámite en oficina:  Cédula de identidad ...  2020-03-29 00:00:00
# 2      Cédula de identidad. Poder notarial simple o ...  2020-04-06 00:00:00
# 3     No es necesario ningún documento. Este es un b...  2020-04-08 00:00:00
# 4          Normal   0         21         false   fal...  2020-04-09 00:00:00
# ...                                                 ...                  ...
# 2520   Fotocopia por ambos lados de la cédula de ide...  2020-04-09 00:00:00
# 2521   Cédula de identidad vigente. Carta firmada po...  2020-04-09 00:00:00
# 2522   Cédula de identidad vigente. Carta firmada po...  2020-04-09 00:00:00
# 2523  Si bien no es necesario ningún documento, se s...  2020-04-09 00:00:00
# 2524  Si bien no es necesario ningún documento, se s...  2020-04-09 00:00:00
#
#      observaciones         temas                       tags chileclic_id  \
# 0                   {'tema': []}                         []         None
# 1                   {'tema': []}                [Previsión]         None
# 2                   {'tema': []}                [Previsión]         None
# 3                   {'tema': []}                    [Bonos]         None
# 4                   {'tema': []}                  [Trabajo]         None
# ...            ...           ...                        ...          ...
# 2520                {'tema': []}           [Salud, Trabajo]         None
# 2521                {'tema': []}     [Consultas y reclamos]         None
# 2522                {'tema': []}  [Salud, Familia, Trabajo]         None
# 2523                {'tema': []}                         []         None
# 2524                {'tema': []}                         []         None
#
#                                               permalink gratis
# 0     https://www.chileatiende.gob.cl/fichas/77607-p...  False
# 1     https://www.chileatiende.gob.cl/fichas/5268-mo...   True
# 2     https://www.chileatiende.gob.cl/fichas/5294-au...   True
# 3     https://www.chileatiende.gob.cl/fichas/77255-b...   True
# 4     https://www.chileatiende.gob.cl/fichas/64062-a...   True
# ...                                                 ...    ...
# 2520  https://www.chileatiende.gob.cl/fichas/3982-re...   True
# 2521  https://www.chileatiende.gob.cl/fichas/22287-r...   True
# 2522  https://www.chileatiende.gob.cl/fichas/28964-a...   True
# 2523  https://www.chileatiende.gob.cl/fichas/59141-s...   True
# 2524  https://www.chileatiende.gob.cl/fichas/59132-s...   True
#
# [2525 rows x 26 columns]

# %%
#prepar la data para elastic search
es.elastic_prepare_pattern()

# %%
#generar bulk data
i=indexes[0]
n=1500
id_field='id'
es.bulk_data(INDEX_NAME=i[0],_type=i[1],n=n,id_field=id_field)
#test
# Out:
# creando paquetes de data bulk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-750926b2cf1d> in <module>
#       3 n=1500
#       4 id_field='id'
# ----> 5 es.bulk_data(INDEX_NAME=i[0],_type=i[1],n=n,id_field=id_field)
#       6 #test
#
# ~/work/modules/Elastic_Module.py in bulk_data(self, INDEX_NAME, _type, n, id_field)
#      91         for idx in range(0,len(data)):
#      92             if len(id_field)>0:
# ---> 93                 _id=data[idx][id_field]+'_'+str(idx)
#      94             else:
#      95                 _id=idx
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#es.chunks[0]

# %%
#es.clear_index(i[0])

# %%
es.bulk_index()

# %%
es.test_index(i[0],n=15)

# %%
es.count_documents(i[0])
